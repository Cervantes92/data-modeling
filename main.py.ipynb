# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#from functools import reduce
from IPython.display import display as dsp

# %%
edu = pd.read_csv('data/SYB61_T07_Education.csv', encoding = "ISO-8859-1")
edu_spend = pd.read_csv('data/SYB61_T09_Public Expenditure on Education.csv', encoding = "ISO-8859-1")
labor = pd.read_csv('data/SYB61_T17_Labour Force and Unemployment.csv', encoding = "ISO-8859-1")
pop = pd.read_csv('data/SYB61_T02_Population, Surface Area and Density.csv', encoding = "ISO-8859-1")
#Source: http://data.un.org/

#IMPORT FILES:
#Education Enrollment areas.
edu.rename(index = str, columns = {'T07': 'Region Code', 
                                   'Enrolment in primary, secondary and tertiary education levels' : 'Region',
                                   'Unnamed: 2': 'Year','Unnamed: 3' : 'Series','Unnamed: 4': 'Value',
                                   'Unnamed: 5': 'Footnotes', 'Unnamed: 6': 'Source'}, inplace = True)
edu.drop(edu.index[0], inplace = True)
edu.index = range(len(edu))
dsp(edu.head())

#Education Expenditure
edu_spend.rename(index = str, columns = {'T09': 'Region Code', 'Public expenditure on education': 'Region',
                                        'Unnamed: 2':'Year', 'Unnamed: 3':'Series', 'Unnamed: 4':'Value',
                                        'Unnamed: 5':'Footnotes', 'Unnamed: 6' : 'Source'}, inplace = True)
edu_spend.drop(edu_spend.index[0], inplace = True)
edu_spend.index = range(len(edu_spend))
dsp(edu_spend.head())

#Labor Force
labor.rename(index = str, columns = {'T17':'Region Code','Labour force participation and unemployment': 'Region',
                                    'Unnamed: 2': 'Year', 'Unnamed: 3':'Series', 'Unnamed: 4':'Value','Unnamed: 5':'Footnotes',
                                    'Unnamed: 6': 'Source'}, inplace = True)
labor.drop(labor.index[0], inplace = True)
labor.index = range(len(labor))
#dsp(labor.head(1))

#Population
pop.rename(index = str, columns = {'T02':'Region Code','Population, density and surface area': 'Region',
                                    'Unnamed: 2': 'Year', 'Unnamed: 3':'Series', 'Unnamed: 4':'Value','Unnamed: 5':'Footnotes',
                                    'Unnamed: 6': 'Source'}, inplace = True)
pop.drop(pop.index[0], inplace = True)
pop.index = range(len(pop))
#dsp(pop.head(1))
# Out:
#   Region Code                         Region  Year  \
# 0           1  Total, all countries or areas  2005
# 1           1  Total, all countries or areas  2005
# 2           1  Total, all countries or areas  2005
# 3           1  Total, all countries or areas  2005
# 4           1  Total, all countries or areas  2005
#
#                                               Series    Value Footnotes  \
# 0  Students enrolled in primary education (thousa...  678,990       NaN
# 1           Gross enrollement ratio - Primary (male)    104.8       NaN
# 2          Gross enrollment ratio - Primary (female)     99.8       NaN
# 3  Students enrolled in secondary education (thou...  509,100       NaN
# 4          Gross enrollment ratio - Secondary (male)     65.7       NaN
#
#                                               Source
# 0  United Nations Educational, Scientific and Cul...
# 1  United Nations Educational, Scientific and Cul...
# 2  United Nations Educational, Scientific and Cul...
# 3  United Nations Educational, Scientific and Cul...
# 4  United Nations Educational, Scientific and Cul...
#   Region Code       Region  Year  \
# 0           4  Afghanistan  2010
# 1           4  Afghanistan  2010
# 2           4  Afghanistan  2010
# 3           4  Afghanistan  2010
# 4           4  Afghanistan  2010
#
#                                               Series Value Footnotes  \
# 0  Current expenditure other than staff compensat...   9.3       NaN
# 1  All staff compensation as % of total expenditu...  72.4       NaN
# 2  Capital expenditure as % of total expenditure ...  18.3       NaN
# 3  Expenditure by level of education: primary (as...  62.1       NaN
# 4  Expenditure by level of education: secondary (...  26.7       NaN
#
#                                               Source
# 0  United Nations Educational, Scientific and Cul...
# 1  United Nations Educational, Scientific and Cul...
# 2  United Nations Educational, Scientific and Cul...
# 3  United Nations Educational, Scientific and Cul...
# 4  United Nations Educational, Scientific and Cul...

# %%
#Stitch measurements into one dataframe and take a few sample countries
dfs = [edu, edu_spend, labor, pop]
#randCodes = ['404', '108', '340', '500', '516', '694', '320', '548', '834', '462']
df = pd.concat(dfs)
df = df.drop(['Footnotes','Source'], axis = 1)
dsp(df.head())

#print('Measures Represented:\n', df['Series'].unique())
#print('Years Represented:\n', df['Year'].unique())

#print(df['Year'].value_counts())

Select_Ser = ['Gross enrollment ratio - Tertiary (male)', 'Gross enrollment ratio - Tertiary (female)', 
              'Labour force participation - Male', 'Unemployment rate - Male',
              'Labour force participation - Female', 'Unemployment rate - Female',
              'Expenditure by level of education: tertiary (as % of government expenditure)',
              'Population mid-year estimates for males (millions)',
              'Population mid-year estimates for females (millions)',
              'All staff compensation as % of total expenditure in public institutions (%)',
              'Capital expenditure as % of total expenditure in public institutions (%)',
              'All staff compensation as % of total expenditure in public institutions (%)']

feat = pd.DataFrame()

###TRANSFORM###
print(df.loc[(df['Series'] == 'Labour force participation - Male') & (df['Region Code'] == '1')]['Value'])

#print('total length):\n', len(df['Year'].unique()) * len(df['Series'].unique()) * len(df['Region Code'].unique()))
feat = pd.DataFrame(df['Region Code'].unique())

for code in df['Region Code']:
    for year in df.loc[df['Region Code'] == code]['Year']:
        for series in Select_Ser:
            #pd.merge(feat, pd.DataFrame(), how = 'left')
            feat[series] = df.loc[(df['Region Code'] == code) & (df['Year'] == year)]['Value']
        
        
feat.head()
# Out:
#   Region Code                         Region  Year  \
# 0           1  Total, all countries or areas  2005
# 1           1  Total, all countries or areas  2005
# 2           1  Total, all countries or areas  2005
# 3           1  Total, all countries or areas  2005
# 4           1  Total, all countries or areas  2005
#
#                                               Series    Value
# 0  Students enrolled in primary education (thousa...  678,990
# 1           Gross enrollement ratio - Primary (male)    104.8
# 2          Gross enrollment ratio - Primary (female)     99.8
# 3  Students enrolled in secondary education (thou...  509,100
# 4          Gross enrollment ratio - Secondary (male)     65.7
# 2     77.4
# 8     76.2
# 14    75.5
# 20    75.0
# Name: Value, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-6362f645659e> in <module>()
#      33         for series in Select_Ser:
#      34             #pd.merge(feat, pd.DataFrame(), how = 'left')
# ---> 35             feat[series] = df.loc[(df['Region Code'] == code) & (df['Year'] == year)]['Value']
#      36
#      37
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3605
#    3606         if isinstance(value, Series):
# -> 3607             value = reindexer(value)
#    3608
#    3609         elif isinstance(value, DataFrame):
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3597                     # duplicate axis
#    3598                     if not value.index.is_unique:
# -> 3599                         raise e
#    3600
#    3601                     # other
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3592                 # GH 4107
#    3593                 try:
# -> 3594                     value = value.reindex(self.index)._values
#    3595                 except Exception as e:
#    3596
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3732     @Appender(generic.NDFrame.reindex.__doc__)
#    3733     def reindex(self, index=None, **kwargs):
# -> 3734         return super(Series, self).reindex(index=index, **kwargs)
#    3735
#    3736     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4372             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    4373                                              fill_value=fill_value,
# -> 4374                                              copy=copy, allow_dups=False)
#    4375
#    4376         return obj
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3084         # trying to reindex on an axis with duplicates
#    3085         if not self.is_unique and len(indexer):
# -> 3086             raise ValueError("cannot reindex from a duplicate axis")
#    3087
#    3088     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %% [markdown]
# # Variables:
#
# 'Gross enrollment ratio - Tertiary (male)'
# 'Gross enrollment ratio - Tertiary (female)',
# 'Labour force participation - Male' 'Unemployment rate - Male',
# 'Labour force participation - Female' 'Unemployment rate - Female',
# 'Expenditure by level of education: tertiary (as % of government expenditure)',
# 'Population mid-year estimates for males (millions)',
# 'Population mid-year estimates for females (millions)',
# 'All staff compensation as % of total expenditure in public institutions (%)',
# 'Capital expenditure as % of total expenditure in public institutions (%)',
# 'All staff compensation as % of total expenditure in public institutions (%)'

# %%
#Filter for select measurements
df2010sr = df2010.loc[df2010['Series'].isin(Select_Ser)]

#Reset index to avoid confusion
#df2010sr.drop(edu.index[0], inplace = True)
#df2010sr.index = range(len(edu))

#Operations:
print('Selected Measurements:\n', Select_Ser)
print('DataFrame Columns:\n',df2010sr.columns)
print('Series:\n', df2010sr['Series'].unique())

dsp(feat.head())

#Create Feature Dataframe
#feat = pd.get_dummies(df2010sr['Region'])
#dsp(feat.head())

#Add Measures to feat dataframe:
#for entry in Select_Ser:
    #feat = pd.concat([feat, df2010sr.loc[df2010sr['Series'] == entry]], axis = 1, join_axes = ['Region Code'], join = 'inner')
    #feat[str(entry)] =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0415f10741fd> in <module>()
#       1 #Filter for select measurements
# ----> 2 df2010sr = df2010.loc[df2010['Series'].isin(Select_Ser)]
#       3
#       4 #Reset index to avoid confusion
#       5 #df2010sr.drop(edu.index[0], inplace = True)
#
# NameError: name 'df2010' is not defined

# %%
#Total, all countries
tot_edu = edu.loc[(edu['Region Code'] == '1'), 
                  ['Year', 'Series', 'Value']]
tot_edu.rename(index = str, columns = {'Series':'Education Demographic','Value':'Edu Measure'}, inplace = True)


tot_labor = labor.loc[(labor['Region Code'] == '1'),
                     ['Year', 'Series', 'Value']]
tot_labor.rename(index = str, columns = {'Series':'Labor Demographic','Value':'Lab Measure'}, inplace = True)


tot_pop = pop.loc[pop['Region Code'] == '1',
                 ['Year','Series', 'Value']]
tot_edu.rename(index = str, columns = {'Series':'Population Demographic','Value':'Pop Measure'}, inplace = True)

#print(tot_pop['Year'].unique())
#print(tot_edu['Year'].unique())
#print(tot_labor['Year'].unique())

#step = pd.merge(tot_labor, tot_pop, on = 'Year', how = 'inner')
#totals = pd.merge(step, tot_edu, on = 'Year', how = 'inner')

#Reset index
